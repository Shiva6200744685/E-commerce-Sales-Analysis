# %%
import pandas as pd #pandas (pd): Data manipulation ke liye use hota hai, jaise CSV file load karna aur process karna.

import numpy as np

# %%
data = pd.read_csv("Sample - Superstore.csv", encoding='latin-1') 
#encoding='latin-1': Special characters ko properly read karne ke liye encoding use hui hai
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
data.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
data['Order Date'] = pd.to_datetime(data['Order Date'])
data['Ship Date'] = pd.to_datetime(data['Ship Date'])

# %%
data['Order Month'] = data['Order Date'].dt.month 
data['Order Year'] = data['Order Date'].dt.year
data['Order Day of Week'] = data['Order Date'].dt.dayofweek

# %%
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#           Category  Sub-Category  \
# 0        Furniture     Bookcases
# 1        Furniture        Chairs
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Grouping sales by month
sales_by_month = data.groupby('Order Month')['Sales'].sum().reset_index()

# Set the figure size
plt.figure(figsize=(10, 5))

# Plot the line chart
sns.lineplot(data=sales_by_month, x='Order Month', y='Sales', marker='o')

# Add title and labels
plt.title('Monthly Sales Analysis')
plt.xlabel('Order Month')
plt.ylabel('Sales')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

# Show the plot
plt.show()

# %%
# Grouping sales by category
sales_by_category = data.groupby('Category')['Sales'].sum().reset_index()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(sales_by_category['Sales'], 
        labels=sales_by_category['Category'], 
        autopct='%1.1f%%',  # Show percentage values
        colors=plt.cm.Pastel1.colors,  # Using pastel colors
        wedgeprops={'edgecolor': 'black'},  # Adding edge for clarity
        startangle=140)  # Rotate for better visualization

# Add title
plt.title('Sales Analysis by Category', fontsize=18)

# Show the plot
plt.show()

# %%
# Grouping sales by sub-category
sales_by_subcategory = data.groupby('Sub-Category')['Sales'].sum().reset_index()

# Set figure size
plt.figure(figsize=(12, 6))

# Create bar chart using Seaborn
sns.barplot(data=sales_by_subcategory, x='Sub-Category', y='Sales', palette='viridis')

# Add title and labels
plt.title('Sales Analysis by Sub-Category', fontsize=16)
plt.xlabel('Sub-Category')
plt.ylabel('Sales')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_15056\1428428208.py:8: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
# Grouping profit by month
profit_by_month = data.groupby('Order Month')['Profit'].sum().reset_index()

# Set figure size
plt.figure(figsize=(10, 5))

# Create line plot using Seaborn
sns.lineplot(data=profit_by_month, x='Order Month', y='Profit', marker='o', color='b')

# Add title and labels
plt.title('Monthly Profit Analysis', fontsize=16)
plt.xlabel('Order Month')
plt.ylabel('Profit')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Grouping profit by category
profit_by_category = data.groupby('Category')['Profit'].sum().reset_index()

# Define colors using a pastel colormap
colors = plt.cm.Pastel1.colors

# Set figure size
plt.figure(figsize=(8, 8))

# Create a donut chart
plt.pie(profit_by_category['Profit'], 
        labels=profit_by_category['Category'], 
        autopct='%1.1f%%',  # Show percentage values
        colors=colors, 
        wedgeprops={'edgecolor': 'black'},  # Add edge for clarity
        startangle=140)

# Add a circle in the center to make it a donut chart
centre_circle = plt.Circle((0, 0), 0.6, fc='white')
plt.gca().add_artist(centre_circle)

# Add title
plt.title('Profit Analysis by Category', fontsize=18)

# Show the plot
plt.show()

# %%
# Grouping profit by sub-category
profit_by_subcategory = data.groupby('Sub-Category')['Profit'].sum().reset_index()

# Set figure size
plt.figure(figsize=(12, 6))

# Create bar chart using Seaborn
sns.barplot(data=profit_by_subcategory, x='Sub-Category', y='Profit', palette='coolwarm')

# Add title and labels
plt.title('Profit Analysis by Sub-Category', fontsize=16)
plt.xlabel('Sub-Category')
plt.ylabel('Profit')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_15056\816384476.py:8: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
# Grouping sales and profit by customer segment
sales_profit_by_segment = data.groupby('Segment').agg({'Sales': 'sum', 'Profit': 'sum'}).reset_index()

# Set figure size
plt.figure(figsize=(10, 6))

# Set width of bars
bar_width = 0.4

# Create bar positions
x_indexes = np.arange(len(sales_profit_by_segment['Segment']))

# Plot Sales and Profit bars
plt.bar(x_indexes - bar_width/2, sales_profit_by_segment['Sales'], width=bar_width, label='Sales', color='skyblue')
plt.bar(x_indexes + bar_width/2, sales_profit_by_segment['Profit'], width=bar_width, label='Profit', color='salmon')

# Add title and labels
plt.title('Sales and Profit Analysis by Customer Segment', fontsize=16)
plt.xlabel('Customer Segment')
plt.ylabel('Amount')

# Set x-axis labels
plt.xticks(ticks=x_indexes, labels=sales_profit_by_segment['Segment'])

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
# Grouping sales and profit by customer segment
sales_profit_by_segment = data.groupby('Segment').agg({'Sales': 'sum', 'Profit': 'sum'}).reset_index()

# Handling division by zero (avoiding infinite or NaN values)
sales_profit_by_segment['Sales_to_Profit_Ratio'] = sales_profit_by_segment['Sales'] / sales_profit_by_segment['Profit'].replace(0, np.nan)

# Display the results
print(sales_profit_by_segment[['Segment', 'Sales_to_Profit_Ratio']])
# Out:
#        Segment  Sales_to_Profit_Ratio
# 0     Consumer               8.659471
# 1    Corporate               7.677245
# 2  Home Office               7.125416
